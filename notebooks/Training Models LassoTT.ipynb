# %%
# Import python packages
import numpy as np
import pandas as pd
import scipy as sp
import sklearn as sk
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Check version numbers
print(f'numpy: {np.version.version}')
print(f'pandas: {pd.__version__}')
print(f'scipy: {sp.__version__}')
print(f'scikit-learn: {sk.__version__}')
print(f'seaborn: {sns.__version__}')
# Out:
# numpy: 2.3.2
# pandas: 2.3.1
# scipy: 1.16.1
# scikit-learn: 1.7.1
# seaborn: 0.13.2

# %%
os.chdir("../data")
print(os.getcwd())
# Out:
# /workspaces/4Geeks_final_project/data

# %%
df = pd.read_csv("clean_superstore_dataset.csv", encoding='latin1')

df.head()
# Out:
#    Row_ID    Order_Date     Sales  Turnaround_Time  Customer_Name_encoded  \
# 0       1  1.510099e+09  261.9600        -259200.0                    166
# 1       2  1.510099e+09  731.9400        -259200.0                    166
# 2       3  1.497226e+09   14.6200        -345600.0                    201
# 3       4  1.476144e+09  957.5775        -604800.0                    687
# 4       5  1.476144e+09   22.3680        -604800.0                    687
#
#    City_encoded  State_encoded  Postal_Code_encoded  Product_ID_encoded  \
# 0           194             15                  215                  12
# 1           194             15                  215                  55
# 2           265              3                  513                 946
# 3           153              8                  168                 319
# 4           153              8                  168                1316
#
#    Ship_Mode_first class  ...  Sub_Category_envelopes  Sub_Category_fasteners  \
# 0                  False  ...                   False                   False
# 1                  False  ...                   False                   False
# 2                  False  ...                   False                   False
# 3                  False  ...                   False                   False
# 4                  False  ...                   False                   False
#
#    Sub_Category_furnishings  Sub_Category_labels  Sub_Category_machines  \
# 0                     False                False                  False
# 1                     False                False                  False
# 2                     False                 True                  False
# 3                     False                False                  False
# 4                     False                False                  False
#
#    Sub_Category_paper  Sub_Category_phones  Sub_Category_storage  \
# 0               False                False                 False
# 1               False                False                 False
# 2               False                False                 False
# 3               False                False                 False
# 4               False                False                  True
#
#    Sub_Category_supplies  Sub_Category_tables
# 0                  False                False
# 1                  False                False
# 2                  False                False
# 3                  False                 True
# 4                  False                False
#
# [5 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Row_ID                    9800 non-null   int64
#  1   Order_Date                9800 non-null   float64
#  2   Sales                     9800 non-null   float64
#  3   Turnaround_Time           9800 non-null   float64
#  4   Customer_Name_encoded     9800 non-null   int64
#  5   City_encoded              9800 non-null   int64
#  6   State_encoded             9800 non-null   int64
#  7   Postal_Code_encoded       9800 non-null   int64
#  8   Product_ID_encoded        9800 non-null   int64
#  9   Ship_Mode_first class     9800 non-null   bool
#  10  Ship_Mode_same day        9800 non-null   bool
#  11  Ship_Mode_second class    9800 non-null   bool
#  12  Ship_Mode_standard class  9800 non-null   bool
#  13  Segment_consumer          9800 non-null   bool
#  14  Segment_corporate         9800 non-null   bool
#  15  Segment_home office       9800 non-null   bool
#  16  Country_united states     9800 non-null   bool
#  17  Region_central            9800 non-null   bool
#  18  Region_east               9800 non-null   bool
#  19  Region_south              9800 non-null   bool
#  20  Region_west               9800 non-null   bool
#  21  Category_furniture        9800 non-null   bool
#  22  Category_office supplies  9800 non-null   bool
#  23  Category_technology       9800 non-null   bool
#  24  Sub_Category_accessories  9800 non-null   bool
#  25  Sub_Category_appliances   9800 non-null   bool
#  26  Sub_Category_art          9800 non-null   bool
#  27  Sub_Category_binders      9800 non-null   bool
#  28  Sub_Category_bookcases    9800 non-null   bool
#  29  Sub_Category_chairs       9800 non-null   bool
#  30  Sub_Category_copiers      9800 non-null   bool
#  31  Sub_Category_envelopes    9800 non-null   bool
#  32  Sub_Category_fasteners    9800 non-null   bool
#  33  Sub_Category_furnishings  9800 non-null   bool
#  34  Sub_Category_labels       9800 non-null   bool
#  35  Sub_Category_machines     9800 non-null   bool
#  36  Sub_Category_paper        9800 non-null   bool
#  37  Sub_Category_phones       9800 non-null   bool
#  38  Sub_Category_storage      9800 non-null   bool
#  39  Sub_Category_supplies     9800 non-null   bool
#  40  Sub_Category_tables       9800 non-null   bool
# dtypes: bool(32), float64(3), int64(6)
# memory usage: 995.4 KB

# %%
from sklearn.model_selection import train_test_split

X = df.drop("Turnaround_Time", axis = 1)
y = df["Turnaround_Time"]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, train_size = 0.80)

# %%
X
# Out:
#       Row_ID    Order_Date     Sales  Customer_Name_encoded  City_encoded  \
# 0          1  1.510099e+09  261.9600                    166           194
# 1          2  1.510099e+09  731.9400                    166           194
# 2          3  1.497226e+09   14.6200                    201           265
# 3          4  1.476144e+09  957.5775                    687           153
# 4          5  1.476144e+09   22.3680                    687           153
# ...      ...           ...       ...                    ...           ...
# 9795    9796  1.495325e+09    3.7980                    663            80
# 9796    9797  1.452557e+09   10.3680                    164           483
# 9797    9798  1.452557e+09  235.1880                    164           483
# 9798    9799  1.452557e+09   26.3760                    164           483
# 9799    9800  1.452557e+09   10.3840                    164           483
#
#       State_encoded  Postal_Code_encoded  Product_ID_encoded  \
# 0                15                  215                  12
# 1                15                  215                  55
# 2                 3                  513                 946
# 3                 8                  168                 319
# 4                 8                  168                1316
# ...             ...                  ...                 ...
# 9795             11                  343                 773
# 9796             33                  223                 515
# 9797             33                  223                1860
# 9798             33                  223                1706
# 9799             33                  223                1470
#
#       Ship_Mode_first class  Ship_Mode_same day  ...  Sub_Category_envelopes  \
# 0                     False               False  ...                   False
# 1                     False               False  ...                   False
# 2                     False               False  ...                   False
# 3                     False               False  ...                   False
# 4                     False               False  ...                   False
# ...                     ...                 ...  ...                     ...
# 9795                  False               False  ...                   False
# 9796                  False               False  ...                   False
# 9797                  False               False  ...                   False
# 9798                  False               False  ...                   False
# 9799                  False               False  ...                   False
#
#       Sub_Category_fasteners  Sub_Category_furnishings  Sub_Category_labels  \
# 0                      False                     False                False
# 1                      False                     False                False
# 2                      False                     False                 True
# 3                      False                     False                False
# 4                      False                     False                False
# ...                      ...                       ...                  ...
# 9795                   False                     False                False
# 9796                   False                     False                False
# 9797                   False                     False                False
# 9798                   False                     False                False
# 9799                   False                     False                False
#
#       Sub_Category_machines  Sub_Category_paper  Sub_Category_phones  \
# 0                     False               False                False
# 1                     False               False                False
# 2                     False               False                False
# 3                     False               False                False
# 4                     False               False                False
# ...                     ...                 ...                  ...
# 9795                  False               False                False
# 9796                  False               False                False
# 9797                  False               False                 True
# 9798                  False               False                 True
# 9799                  False               False                False
#
#       Sub_Category_storage  Sub_Category_supplies  Sub_Category_tables
# 0                    False                  False                False
# 1                    False                  False                False
# 2                    False                  False                False
# 3                    False                  False                 True
# 4                     True                  False                False
# ...                    ...                    ...                  ...
# 9795                 False                  False                False
# 9796                 False                  False                False
# 9797                 False                  False                False
# 9798                 False                  False                False
# 9799                 False                  False                False
#
# [9800 rows x 40 columns]

# %%
y
# Out:
# 0      -259200.0
# 1      -259200.0
# 2      -345600.0
# 3      -604800.0
# 4      -604800.0
#           ...
# 9795   -604800.0
# 9796   -432000.0
# 9797   -432000.0
# 9798   -432000.0
# 9799   -432000.0
# Name: Turnaround_Time, Length: 9800, dtype: float64

# %%
from sklearn.linear_model import Lasso

# Load of train and test data
# These data must have been standardized and correctly processed in a complete EDA

lasso_model = Lasso(alpha = 0.1, max_iter = 300)

lasso_model.fit(X_train, y_train)
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.864e+13, tolerance: 1.791e+10
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.1, max_iter=300)

# %%
print(f"Intercept (a): {lasso_model.intercept_}")
print(f"Coefficients (b): {lasso_model.coef_}")
# Out:
# Intercept (a): -317376.62321779726
# Coefficients (b): [ 3.96097591e-01 -5.01112509e-05 -3.08121041e-01 -7.04992025e+00
#  -3.14814263e+00  6.46989500e+01  4.19502652e+01 -1.63694191e+01
#   2.10839144e+05  3.95381848e+05  1.18589381e+05 -3.38879984e+04
#  -0.00000000e+00 -5.59358152e+02  5.41797235e+02  0.00000000e+00
#  -1.10498785e+03  1.28734767e+04  1.00990339e+04 -7.88164387e+03
#  -1.20264219e+04 -7.34978059e+03  6.42519081e+03 -2.84403775e+03
#  -6.34061692e+03 -9.31189740e+03 -1.95036036e+03 -6.45497826e+03
#  -5.61426706e+03  5.94555758e+03 -2.72061699e+03 -1.34499251e+02
#  -4.75334486e+03  1.17471383e+03  5.13596855e+03  3.86261766e+03
#  -8.32086113e+02  5.75268251e+03  2.42363933e+03 -3.27887156e+03]

# %%
y_pred = lasso_model.predict(X_test)
y_pred
# Out:
# array([-436909.07274648, -436559.83744218,   -9756.00005176, ...,
#        -182393.02786433, -434073.85249819, -430207.72199333],
#       shape=(1960,))

# %%
from sklearn.metrics import mean_squared_error as mse , r2_score

print(f"Mean squared error: {mse(y_test, y_pred)}")
print(f"Coefficient of determination: {r2_score(y_test, y_pred)}")
# Out:
# Mean squared error: 7203568770.083111
# Coefficient of determination: 0.6848661131442624

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100], 
             'max_iter':[500, 1000, 5000]}

grid_search = GridSearchCV(lasso_model, param_grid, cv=5, scoring='neg_mean_squared_error')

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

grid_search.fit(X_train, y_train)

print(f"Best hyperparameters: {grid_search.best_params_}")
# Out:
# Best hyperparameters: {'alpha': 100, 'max_iter': 500}

# %%
best_model = Lasso( alpha = 100, max_iter = 500)

best_model.fit(X_train, y_train)
y_pred2 = best_model.predict(X_test)

print(f"Mean squared error: {mse(y_test, y_pred2)}")
print(f"Coefficient of determination: {r2_score(y_test, y_pred2)}")
# Out:
# Mean squared error: 7198786531.70405
# Coefficient of determination: 0.6850753213043237

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.7, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # reference line
plt.xlabel("Actual Turnaround Time")
plt.ylabel("Predicted Turnaround Time")
plt.title("Actual vs. Predicted Turnaround Time")
plt.grid(True)
plt.show()

# %%
residuals = y_test - y_pred

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, residuals, alpha=0.7, color='purple')
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals (Actual - Predicted)")
plt.title("Residuals vs. Predicted Values")
plt.grid(True)
plt.show()
