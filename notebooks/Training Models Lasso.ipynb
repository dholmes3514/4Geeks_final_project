# %%
# Import python packages
import numpy as np
import pandas as pd
import scipy as sp
import sklearn as sk
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Check version numbers
print(f'numpy: {np.version.version}')
print(f'pandas: {pd.__version__}')
print(f'scipy: {sp.__version__}')
print(f'scikit-learn: {sk.__version__}')
print(f'seaborn: {sns.__version__}')
# Out:
# numpy: 2.3.2
# pandas: 2.3.1
# scipy: 1.16.1
# scikit-learn: 1.7.1
# seaborn: 0.13.2

# %%
os.chdir("../data")
print(os.getcwd())
# Out:
# /workspaces/4Geeks_final_project/data

# %%
df = pd.read_csv("clean_superstore_dataset.csv", encoding='latin1')

df.head()
# Out:
#    Row_ID   Order_Date     Sales  Turnaround_Time  Customer_Name_encoded  \
# 0       1  15100992000  261.9600         259200.0                    166
# 1       2  15100992000  731.9400         259200.0                    166
# 2       3  14972256000   14.6200         345600.0                    201
# 3       4  14761440000  957.5775         604800.0                    687
# 4       5  14761440000   22.3680         604800.0                    687
#
#    City_encoded  State_encoded  Postal_Code_encoded  Product_ID_encoded  \
# 0           193             15                  215                  12
# 1           193             15                  215                  55
# 2           264              3                  512                 943
# 3           152              8                  168                 319
# 4           152              8                  168                1313
#
#    Ship_Mode_first class  ...  Sub_Category_envelopes  Sub_Category_fasteners  \
# 0                  False  ...                   False                   False
# 1                  False  ...                   False                   False
# 2                  False  ...                   False                   False
# 3                  False  ...                   False                   False
# 4                  False  ...                   False                   False
#
#    Sub_Category_furnishings  Sub_Category_labels  Sub_Category_machines  \
# 0                     False                False                  False
# 1                     False                False                  False
# 2                     False                 True                  False
# 3                     False                False                  False
# 4                     False                False                  False
#
#    Sub_Category_paper  Sub_Category_phones  Sub_Category_storage  \
# 0               False                False                 False
# 1               False                False                 False
# 2               False                False                 False
# 3               False                False                 False
# 4               False                False                  True
#
#    Sub_Category_supplies  Sub_Category_tables
# 0                  False                False
# 1                  False                False
# 2                  False                False
# 3                  False                 True
# 4                  False                False
#
# [5 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9557 entries, 0 to 9556
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Row_ID                    9557 non-null   int64
#  1   Order_Date                9557 non-null   int64
#  2   Sales                     9557 non-null   float64
#  3   Turnaround_Time           9557 non-null   float64
#  4   Customer_Name_encoded     9557 non-null   int64
#  5   City_encoded              9557 non-null   int64
#  6   State_encoded             9557 non-null   int64
#  7   Postal_Code_encoded       9557 non-null   int64
#  8   Product_ID_encoded        9557 non-null   int64
#  9   Ship_Mode_first class     9557 non-null   bool
#  10  Ship_Mode_same day        9557 non-null   bool
#  11  Ship_Mode_second class    9557 non-null   bool
#  12  Ship_Mode_standard class  9557 non-null   bool
#  13  Segment_consumer          9557 non-null   bool
#  14  Segment_corporate         9557 non-null   bool
#  15  Segment_home office       9557 non-null   bool
#  16  Country_united states     9557 non-null   bool
#  17  Region_central            9557 non-null   bool
#  18  Region_east               9557 non-null   bool
#  19  Region_south              9557 non-null   bool
#  20  Region_west               9557 non-null   bool
#  21  Category_furniture        9557 non-null   bool
#  22  Category_office supplies  9557 non-null   bool
#  23  Category_technology       9557 non-null   bool
#  24  Sub_Category_accessories  9557 non-null   bool
#  25  Sub_Category_appliances   9557 non-null   bool
#  26  Sub_Category_art          9557 non-null   bool
#  27  Sub_Category_binders      9557 non-null   bool
#  28  Sub_Category_bookcases    9557 non-null   bool
#  29  Sub_Category_chairs       9557 non-null   bool
#  30  Sub_Category_copiers      9557 non-null   bool
#  31  Sub_Category_envelopes    9557 non-null   bool
#  32  Sub_Category_fasteners    9557 non-null   bool
#  33  Sub_Category_furnishings  9557 non-null   bool
#  34  Sub_Category_labels       9557 non-null   bool
#  35  Sub_Category_machines     9557 non-null   bool
#  36  Sub_Category_paper        9557 non-null   bool
#  37  Sub_Category_phones       9557 non-null   bool
#  38  Sub_Category_storage      9557 non-null   bool
#  39  Sub_Category_supplies     9557 non-null   bool
#  40  Sub_Category_tables       9557 non-null   bool
# dtypes: bool(32), float64(2), int64(7)
# memory usage: 970.8 KB

# %%
from sklearn.model_selection import train_test_split

X = df.drop("Sales", axis = 1)
y = df["Sales"]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, train_size = 0.80)

# %%
X
# Out:
#       Row_ID   Order_Date  Turnaround_Time  Customer_Name_encoded  \
# 0          1  15100992000         259200.0                    166
# 1          2  15100992000         259200.0                    166
# 2          3  14972256000         345600.0                    201
# 3          4  14761440000         604800.0                    687
# 4          5  14761440000         604800.0                    687
# ...      ...          ...              ...                    ...
# 9552    9796  14953248000         604800.0                    663
# 9553    9797  14525568000         432000.0                    164
# 9554    9798  14525568000         432000.0                    164
# 9555    9799  14525568000         432000.0                    164
# 9556    9800  14525568000         432000.0                    164
#
#       City_encoded  State_encoded  Postal_Code_encoded  Product_ID_encoded  \
# 0              193             15                  215                  12
# 1              193             15                  215                  55
# 2              264              3                  512                 943
# 3              152              8                  168                 319
# 4              152              8                  168                1313
# ...            ...            ...                  ...                 ...
# 9552            79             11                  343                 770
# 9553           482             33                  223                 514
# 9554           482             33                  223                1840
# 9555           482             33                  223                1687
# 9556           482             33                  223                1466
#
#       Ship_Mode_first class  Ship_Mode_same day  ...  Sub_Category_envelopes  \
# 0                     False               False  ...                   False
# 1                     False               False  ...                   False
# 2                     False               False  ...                   False
# 3                     False               False  ...                   False
# 4                     False               False  ...                   False
# ...                     ...                 ...  ...                     ...
# 9552                  False               False  ...                   False
# 9553                  False               False  ...                   False
# 9554                  False               False  ...                   False
# 9555                  False               False  ...                   False
# 9556                  False               False  ...                   False
#
#       Sub_Category_fasteners  Sub_Category_furnishings  Sub_Category_labels  \
# 0                      False                     False                False
# 1                      False                     False                False
# 2                      False                     False                 True
# 3                      False                     False                False
# 4                      False                     False                False
# ...                      ...                       ...                  ...
# 9552                   False                     False                False
# 9553                   False                     False                False
# 9554                   False                     False                False
# 9555                   False                     False                False
# 9556                   False                     False                False
#
#       Sub_Category_machines  Sub_Category_paper  Sub_Category_phones  \
# 0                     False               False                False
# 1                     False               False                False
# 2                     False               False                False
# 3                     False               False                False
# 4                     False               False                False
# ...                     ...                 ...                  ...
# 9552                  False               False                False
# 9553                  False               False                False
# 9554                  False               False                 True
# 9555                  False               False                 True
# 9556                  False               False                False
#
#       Sub_Category_storage  Sub_Category_supplies  Sub_Category_tables
# 0                    False                  False                False
# 1                    False                  False                False
# 2                    False                  False                False
# 3                    False                  False                 True
# 4                     True                  False                False
# ...                    ...                    ...                  ...
# 9552                 False                  False                False
# 9553                 False                  False                False
# 9554                 False                  False                False
# 9555                 False                  False                False
# 9556                 False                  False                False
#
# [9557 rows x 40 columns]

# %%
y
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9552      3.7980
# 9553     10.3680
# 9554    235.1880
# 9555     26.3760
# 9556     10.3840
# Name: Sales, Length: 9557, dtype: float64

# %%
from sklearn.linear_model import Lasso

# Load of train and test data
# These data must have been standardized and correctly processed in a complete EDA

lasso_model = Lasso(alpha = 0.1, max_iter = 300)

lasso_model.fit(X_train, y_train)
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.727e+08, tolerance: 5.010e+04
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.1, max_iter=300)

# %%
print(f"Intercept (a): {lasso_model.intercept_}")
print(f"Coefficients (b): {lasso_model.coef_}")
# Out:
# Intercept (a): 387.9839372168839
# Coefficients (b): [-1.60351508e-03 -9.22273532e-09 -5.33846613e-05  4.09314537e-03
#   2.36781172e-02 -1.39469181e-01 -8.61379229e-02  5.47571565e-02
#  -9.87144986e+00 -4.90463771e+00  1.08805905e-02  8.10588142e+00
#  -1.80297266e+00  1.67493333e+00 -0.00000000e+00  0.00000000e+00
#   6.44175518e-02 -1.64987778e+01 -1.24115535e+00  2.44323461e+01
#   1.86195755e+02 -1.99433970e+02  0.00000000e+00 -9.78111324e+01
#   1.44650450e+02 -3.30300386e+00  1.79340876e+01 -0.00000000e+00
#   3.67459164e+01  5.19007067e+02  0.00000000e+00 -4.04037727e+01
#  -3.11885713e+02 -2.32238295e+01  1.67033426e+02 -1.30954892e+01
#  -0.00000000e+00  1.62176703e+02 -2.13802381e+01  7.63868216e+01]

# %%
y_pred = lasso_model.predict(X_test)
y_pred
# Out:
# array([246.21938123, 239.22231909,  62.29511638, ..., 190.82808226,
#         54.56917755, 448.09079056], shape=(1912,))

# %%
from sklearn.metrics import mean_squared_error as mse , r2_score

print(f"Mean squared error: {mse(y_test, y_pred)}")
print(f"Coefficient of determination: {r2_score(y_test, y_pred)}")
# Out:
# Mean squared error: 44337.91564415807
# Coefficient of determination: 0.2982919702247815

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100], 
             'max_iter':[500, 1000, 5000]}

grid_search = GridSearchCV(lasso_model, param_grid, cv=5, scoring='neg_mean_squared_error')

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

grid_search.fit(X_train, y_train)

print(f"Best hyperparameters: {grid_search.best_params_}")
# Out:
# Best hyperparameters: {'alpha': 0.01, 'max_iter': 1000}

# %%
best_model = Lasso( alpha = 0.1, max_iter = 1000)

best_model.fit(X_train, y_train)
y_pred2 = best_model.predict(X_test)

print(f"Mean squared error: {mse(y_test, y_pred2)}")
print(f"Coefficient of determination: {r2_score(y_test, y_pred2)}")
# Out:
# Mean squared error: 44326.52491295947
# Coefficient of determination: 0.29847224409266504

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.7, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # reference line
plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.title("Actual vs. Predicted Sales")
plt.grid(True)
plt.show()

# %%
residuals = y_test - y_pred

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, residuals, alpha=0.7, color='purple')
plt.axhline(y=0, color='red', linestyle='--')  # reference line at zero
plt.xlabel("Predicted Values")
plt.ylabel("Residuals (Actual - Predicted)")
plt.title("Residuals vs. Predicted Values")
plt.grid(True)
plt.show()
